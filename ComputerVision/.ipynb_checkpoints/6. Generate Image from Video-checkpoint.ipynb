# %% [markdown]
# Helper link https://www.geeksforgeeks.org/python-play-a-video-using-opencv/?ref=lbp

# %% [markdown]
# # Loading librarys

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
from pathlib import Path, PureWindowsPath
from glob import glob

from PIL import Image
import cv2
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K
from tensorflow.keras.utils import *
from tensorflow.keras.regularizers import *

# %% [markdown]
# # video file path

# %%
files = os.listdir('c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\VideoData')
# for i,j in enumerate(files):
#     print('{j} folder is lebel {i}'.format(i=i, j=j))

for i in files:
    print(i)
# Out:
# seg_comp1.mp4
# seg_comp2.mp4

# %% [markdown]
# # Play a video using OpenCV

# %%
v = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\VideoData"
v
# Out:
# 'C:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\VideoData'

# %%
## cv2.VideoCapture(0): Means first camera or webcam.
## cv2.VideoCapture(1):  Means second camera or webcam.
## cv2.VideoCapture(“file name.mp4”): Means video file

## Create a VideoCapture object and read from input file, different way to pass file path
# cap = cv2.VideoCapture('c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\\
# Dataset\\VideoData\\seg_comp1.mp4') 

# cap = cv2.VideoCapture(r'c:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\
# VideoData\seg_comp1.mp4')

# base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\VideoData"
# cap = cv2.VideoCapture(base_path + '\seg_comp1.mp4')

base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cap = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4')

# Check if camera opened successfully 
if (cap.isOpened() == False): 
    print("Error opening video file") 

# Read until video is completed 
while(cap.isOpened()): 
      
# Capture frame-by-frame
    
    ret, frame = cap.read() 
    if ret == True: 
    # Display resulting frame 
        cv2.imshow('Frame', frame) 
          
    # Press Q on keyboard to exit 
        if cv2.waitKey(25) & 0xFF == ord('q'): 
            break
  
# Break the loop 
    else: 
        break
# When everything done, release video capture object 
cap.release() 
  
# Closes all frames 
cv2.destroyAllWindows()

# %% [markdown]
# # Create video using multiple images using OpenCV

# %%
# Folder which contains all the images from which video is to be generated

base_path = "c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\Assignment1\\n01440764"
des_path = "c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\NewVideo"
# os.chdir("c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\Assignment1\\n01440764")   

mean_height = 0
mean_width = 0
  
num_of_images = len(os.listdir(base_path + '.'))
print(num_of_images) 

for file in os.listdir(base_path + '.'): 
    im = Image.open(os.path.join(base_path, file)) 
    width, height = im.size 
    mean_width += width 
    mean_height += height 
    # im.show()   # uncomment this for displaying image 
  
# Finding mean height and width of all images as This is required because video frame needs 
# to be set with same width and height, Otherwise images not equal to that width height will not get embedded into video 
mean_width = int(mean_width / num_of_images) 
mean_height = int(mean_height / num_of_images) 
  
# print(mean_height) 
# print(mean_width) 
  
# Resizing of images to give them same width and height  
for file in os.listdir(base_path + '.'): 
    if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith("png") or file.endswith("JPEG"): 
        # opening image using PIL Image 
        im = Image.open(os.path.join(base_path, file))  
   
        # im.size includes height and width of image 
        width, height = im.size    
        print(width, height) 
  
        # resizing  
        # imResize = im.resize((mean_width, mean_height), Image.ANTIALIAS)
        imResize = im.resize((mean_width, mean_height))
        # imResize.save(file,'JPEG', quality = 95) # setting quality
        imResize.save(os.path.join(des_path, file),'JPEG', quality = 95) # setting quality and saving in new path
        # printing each resized image name 
        print(im.filename.split('\\')[-1], " is resized")  

# Video Generating function 
def generate_video(): 
    image_folder = des_path+'.' 
    video_name = 'mygeneratedvideo.avi'
    #os.chdir("C:\\Python\\Geekfolder2") 
      
    images = [img for img in os.listdir(image_folder) if img.endswith(".jpg") or img.endswith(".jpeg") or 
              img.endswith("JPEG") or img.endswith("png")] 
     
    # Array images should only consider image files ignoring others if any 
    print(images)  
  
    frame = cv2.imread(os.path.join(image_folder, images[0])) 
  
    # setting frame width, height of first image 
    height, width, layers = frame.shape   
  
    # video = cv2.VideoWriter(video_name, 0, 1, (width, height))
    video = cv2.VideoWriter(os.path.join(des_path, video_name), 0, 1, (width, height)) # saving to selected folder
  
    # Appending images to video one by one 
    for image in images:  
        video.write(cv2.imread(os.path.join(image_folder, image)))  
      
    # Deallocating memories taken for window creation 
    cv2.destroyAllWindows()  
    video.release()  # releasing video generated 
  
# Calling the generate_video function 
generate_video()
# Out:
# 30
# 500 375
# n01440764_105.JPEG  is resized
# 75 56
# n01440764_107.JPEG  is resized
# 500 334
# n01440764_137.JPEG  is resized
# 2048 1536
# n01440764_141.JPEG  is resized
# 2304 1728
# n01440764_148.JPEG  is resized
# 300 189
# n01440764_172.JPEG  is resized
# 375 500
# n01440764_18.JPEG  is resized
# 400 300
# n01440764_188.JPEG  is resized
# 80 60
# n01440764_190.JPEG  is resized
# 400 321
# n01440764_192.JPEG  is resized
# 500 375
# n01440764_200.JPEG  is resized
# 300 200
# n01440764_237.JPEG  is resized
# 250 189
# n01440764_239.JPEG  is resized
# 425 239
# n01440764_261.JPEG  is resized
# 500 375
# n01440764_292.JPEG  is resized
# 100 70
# n01440764_297.JPEG  is resized
# 800 600
# n01440764_298.JPEG  is resized
# 500 375
# n01440764_315.JPEG  is resized
# 368 500
# n01440764_320.JPEG  is resized
# 800 600
# n01440764_334.JPEG  is resized
# 350 221
# n01440764_341.JPEG  is resized
# 200 150
# n01440764_36.JPEG  is resized
# 640 480
# n01440764_37.JPEG  is resized
# 500 334
# n01440764_39.JPEG  is resized
# 400 287
# n01440764_44.JPEG  is resized
# 300 195
# n01440764_63.JPEG  is resized
# 500 375
# n01440764_73.JPEG  is resized
# 940 705
# n01440764_78.JPEG  is resized
# 500 375
# n01440764_96.JPEG  is resized
# 500 375
# n01440764_97.JPEG  is resized
# ['n01440764_105.JPEG', 'n01440764_107.JPEG', 'n01440764_137.JPEG', 'n01440764_141.JPEG', 'n01440764_148.JPEG', 'n01440764_172.JPEG', 'n01440764_18.JPEG', 'n01440764_188.JPEG', 'n01440764_190.JPEG', 'n01440764_192.JPEG', 'n01440764_200.JPEG', 'n01440764_237.JPEG', 'n01440764_239.JPEG', 'n01440764_261.JPEG', 'n01440764_292.JPEG', 'n01440764_297.JPEG', 'n01440764_298.JPEG', 'n01440764_315.JPEG', 'n01440764_320.JPEG', 'n01440764_334.JPEG', 'n01440764_341.JPEG', 'n01440764_36.JPEG', 'n01440764_37.JPEG', 'n01440764_39.JPEG', 'n01440764_44.JPEG', 'n01440764_63.JPEG', 'n01440764_73.JPEG', 'n01440764_78.JPEG', 'n01440764_96.JPEG', 'n01440764_97.JPEG']

# %%
# test work 

# Folder which contains all the images from which video is to be generated

# base_path = "c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\Assignment1\\n01440764"
base_path = "c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\seg_image_all"
des_path = "c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\NewVideo"
# os.chdir("c:\\Users\\SHEHA\\Downloads\\GitHubRepository\\Python2022\\ComputerVision\\Dataset\\Assignment1\\n01440764")   

# mean_height = 0
# mean_width = 0
  
# num_of_images = len(os.listdir(base_path + '.'))
# print(num_of_images) 

# for file in os.listdir(base_path + '.'): 
#     im = Image.open(os.path.join(base_path, file)) 
#     width, height = im.size 
#     mean_width += width 
#     mean_height += height 
#     # im.show()   # uncomment this for displaying image 
  
## Finding mean height and width of all images as This is required because video frame needs 
## to be set with same width and height, Otherwise images not equal to that width height will not get embedded into video

# mean_width = int(mean_width / num_of_images) 
# mean_height = int(mean_height / num_of_images) 
  
# print(mean_height) 
# print(mean_width) 
  
## Resizing of images to give them same width and height  
# for file in os.listdir(base_path + '.'): 
#     if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith("png") or file.endswith("JPEG"): 
#         # opening image using PIL Image 
#         im = Image.open(os.path.join(base_path, file))  
   
#         # im.size includes height and width of image 
#         width, height = im.size    
#         #print(width, height) 
  
#         # resizing  
#         # imResize = im.resize((mean_width, mean_height), Image.ANTIALIAS)
#         imResize = im.resize((mean_width, mean_height))
#         # imResize.save(file,'JPEG', quality = 95) # setting quality
#         imResize.save(os.path.join(des_path, file),'JPEG', quality = 95) # setting quality and saving in new path
#         # printing each resized image name 
#         print(im.filename.split('\\')[-1], " is resized")  

# Video Generating function 
def generate_video(): 
    image_folder = base_path+'.' 
    video_name = 'mysegvideo.avi'
    #os.chdir("C:\\Python\\Geekfolder2") 
      
    images = [img for img in os.listdir(image_folder) if img.endswith(".jpg") or img.endswith(".jpeg") or 
              img.endswith("JPEG") or img.endswith("png")] 
     
    # Array images should only consider image files ignoring others if any 
    print(images)  
  
    frame = cv2.imread(os.path.join(image_folder, images[0])) 
  
    # setting frame width, height of first image 
    height, width, layers = frame.shape   
  
    # video = cv2.VideoWriter(video_name, 0, 1, (width, height))
    video = cv2.VideoWriter(os.path.join(des_path, video_name), 0, 1, (width, height)) # saving to selected folder
  
    # Appending images to video one by one 
    for image in images:  
        video.write(cv2.imread(os.path.join(image_folder, image)))  
      
    # Deallocating memories taken for window creation 
    cv2.destroyAllWindows()  
    video.release()  # releasing video generated 
  
# Calling the generate_video function 
generate_video()

# %% [markdown]
# # Extract images from video

# %% [markdown]
# help link: https://stackoverflow.com/questions/25359288/how-to-know-total-number-of-frame-in-a-file-with-cv2-in-python

# %%
# total number of Frame in a file with cv2 in python

def frame_count(video_path, manual=False):
    def manual_count(handler):
        frames = 0
        while True:
            status, frame = handler.read()
            if not status:
                break
            frames += 1
        return frames 

    cap = cv2.VideoCapture(video_path)
    # Slow, inefficient but 100% accurate method 
    if manual:
        frames = manual_count(cap)
    # Fast, efficient but inaccurate method
    else:
        try:
            frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        except:
            frames = manual_count(cap)
    cap.release()
    return frames

# %%
import timeit

vid_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\VideoData\seg_comp1.mp4"

print("fast method")
start = timeit.default_timer()
print('frames:', frame_count(vid_path, manual=False))
print(timeit.default_timer() - start, '(s)')

print("\nslow method")
start = timeit.default_timer()
print('frames:', frame_count(vid_path, manual=True))
print(timeit.default_timer() - start, '(s)')
# Out:
# fast method
# frames: 1829
# 0.03213569999934407 (s)
#
# slow method
# frames: 1829
# 5.269488300000376 (s)

# %%
### Extract images from video

# VideoCapture(File_path) : Read the video(.mp4 format)
# read() : Read data depending upon the type of object that calls
# imwrite(filename, img[, params]) : Saves an image to a specified file.

base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cam = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 
  
try: 

    # creating a folder named seg_image
    if not os.path.exists(r'C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image'): 
        os.makedirs(r'C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of seg_image') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret, frame = cam.read() 
    if ret: 
        # if video is still left continue creating images 
        name = base_path + '\seg_image\image' + str(currentframe) + '.jpg'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()

# %%
name = base_path + '\seg_image\image' + str(currentframe) + '.jpg'
print ('Creating...' + name)
# Out:
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image\image1829.jpg

# %%
base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cam = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 
  
try: 

    # creating a folder named seg_image
    if not os.path.exists(r'C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all'): 
        os.makedirs(r'C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of seg_image') 
  
# frame 
currentframe = 0
sgimage = 0

while(True): 
      
    # reading from frame 
    ret, frame = cam.read()

    #currentframe += 1
    if ret:
    #if currentframe%70 == 0: 
        # if video is still left continue creating images 
        # name = base_path + '\seg_image\image' + str(currentframe) + '.jpg'
        name = base_path + '\seg_image_all\image' + str(sgimage) + '.jpg'
        print('Creating...' + name) 
    
        # writing the extracted images 
        cv2.imwrite(name, frame) 
        print(frame.shape)
        sgimage +=1
        # increasing counter so that it will 
        # show how many frames are created
        
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image0.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image2.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image3.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image4.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image5.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image6.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image7.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image8.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image9.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image10.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image11.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image12.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image13.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image14.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image15.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image16.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image17.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image18.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image19.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image20.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image21.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image22.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image23.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image24.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image25.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image26.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image27.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image28.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image29.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image30.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image31.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image32.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image33.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image34.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image35.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image36.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image37.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image38.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image39.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image40.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image41.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image42.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image43.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image44.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image45.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image46.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image47.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image48.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image49.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image50.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image51.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image52.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image53.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image54.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image55.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image56.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image57.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image58.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image59.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image60.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image61.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image62.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image63.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image64.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image65.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image66.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image67.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image68.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image69.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image70.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image71.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image72.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image73.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image74.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image75.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image76.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image77.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image78.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image79.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image80.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image81.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image82.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image83.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image84.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image85.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image86.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image87.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image88.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image89.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image90.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image91.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image92.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image93.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image94.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image95.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image96.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image97.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image98.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image99.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image100.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image101.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image102.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image103.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image104.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image105.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image106.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image107.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image108.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image109.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image110.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image111.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image112.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image113.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image114.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image115.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image116.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image117.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image118.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image119.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image120.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image121.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image122.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image123.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image124.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image125.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image126.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image127.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image128.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image129.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image130.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image131.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image132.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image133.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image134.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image135.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image136.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image137.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image138.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image139.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image140.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image141.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image142.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image143.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image144.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image145.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image146.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image147.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image148.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image149.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image150.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image151.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image152.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image153.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image154.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image155.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image156.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image157.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image158.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image159.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image160.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image161.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image162.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image163.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image164.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image165.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image166.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image167.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image168.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image169.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image170.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image171.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image172.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image173.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image174.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image175.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image176.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image177.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image178.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image179.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image180.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image181.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image182.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image183.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image184.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image185.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image186.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image187.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image188.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image189.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image190.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image191.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image192.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image193.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image194.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image195.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image196.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image197.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image198.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image199.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image200.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image201.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image202.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image203.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image204.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image205.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image206.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image207.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image208.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image209.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image210.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image211.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image212.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image213.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image214.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image215.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image216.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image217.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image218.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image219.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image220.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image221.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image222.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image223.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image224.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image225.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image226.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image227.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image228.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image229.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image230.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image231.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image232.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image233.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image234.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image235.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image236.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image237.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image238.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image239.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image240.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image241.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image242.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image243.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image244.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image245.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image246.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image247.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image248.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image249.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image250.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image251.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image252.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image253.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image254.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image255.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image256.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image257.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image258.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image259.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image260.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image261.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image262.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image263.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image264.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image265.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image266.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image267.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image268.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image269.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image270.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image271.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image272.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image273.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image274.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image275.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image276.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image277.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image278.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image279.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image280.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image281.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image282.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image283.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image284.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image285.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image286.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image287.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image288.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image289.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image290.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image291.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image292.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image293.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image294.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image295.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image296.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image297.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image298.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image299.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image300.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image301.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image302.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image303.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image304.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image305.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image306.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image307.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image308.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image309.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image310.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image311.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image312.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image313.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image314.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image315.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image316.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image317.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image318.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image319.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image320.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image321.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image322.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image323.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image324.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image325.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image326.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image327.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image328.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image329.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image330.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image331.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image332.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image333.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image334.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image335.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image336.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image337.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image338.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image339.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image340.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image341.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image342.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image343.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image344.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image345.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image346.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image347.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image348.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image349.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image350.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image351.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image352.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image353.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image354.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image355.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image356.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image357.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image358.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image359.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image360.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image361.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image362.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image363.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image364.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image365.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image366.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image367.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image368.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image369.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image370.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image371.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image372.jpg
# ...
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1706.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1707.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1708.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1709.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1710.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1711.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1712.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1713.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1714.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1715.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1716.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1717.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1718.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1719.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1720.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1721.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1722.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1723.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1724.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1725.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1726.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1727.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1728.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1729.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1730.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1731.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1732.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1733.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1734.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1735.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1736.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1737.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1738.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1739.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1740.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1741.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1742.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1743.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1744.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1745.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1746.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1747.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1748.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1749.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1750.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1751.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1752.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1753.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1754.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1755.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1756.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1757.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1758.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1759.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1760.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1761.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1762.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1763.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1764.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1765.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1766.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1767.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1768.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1769.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1770.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1771.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1772.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1773.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1774.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1775.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1776.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1777.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1778.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1779.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1780.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1781.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1782.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1783.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1784.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1785.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1786.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1787.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1788.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1789.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1790.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1791.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1792.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1793.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1794.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1795.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1796.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1797.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1798.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1799.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1800.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1801.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1802.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1803.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1804.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1805.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1806.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1807.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1808.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1809.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1810.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1811.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1812.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1813.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1814.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1815.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1816.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1817.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1818.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1819.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1820.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1821.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1822.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1823.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1824.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1825.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1826.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1827.jpg
# (720, 1280, 3)
# Creating...C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image_all\image1828.jpg
# (720, 1280, 3)

# %% [markdown]
# # Capture Video from Camera

# %%
# Steps to capture a video:
# Use cv2.VideoCapture() to get a video capture object for the camera.
# Set up an infinite while loop and use the read() method to read the frames using the above created object.
# Use cv2.imshow() method to show the frames in the video.
# Breaks the loop when the user clicks a specific key.

# define a video capture object 
vid = cv2.VideoCapture(0) 
  
while(True): 
      
    # Capture video frame by frame 
    ret, frame = vid.read() 
  
    # Display resulting frame 
    cv2.imshow('frame', frame) 
      
    # the 'q' button is set as quitting button, may use any desired button of your choice 
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
  
# After the loop release the cap object 
vid.release() 
# Destroy all the windows 
cv2.destroyAllWindows()

# %% [markdown]
# # Process images of a video using OpenCV

# %%
# Creating a VideoCapture object to read video
# Processing a video means, performing operations on the video frame by frame. Frames are nothing but just the particular instance of the video 
# in a single point of time. We may have multiple frames even in a single second. Frames can be treated as similar to an image.
# So, whatever operations we can perform on images can be performed on frames as well.

# By using this technique we can apply thresholding on small regions of the frame. So the collective value will be different for the whole frame. 

base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cap = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 

# Loop until end of video
while (cap.isOpened()):
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True: 
            frame = cv2.resize(frame, (540, 380), fx = 0, fy = 0, interpolation = cv2.INTER_CUBIC)
            
            # Display resulting frame
            cv2.imshow('Frame', frame)
            
            # conversion of BGR to grayscale is necessary to apply this operation
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            
            # adaptive thresholding to use different threshold values on different regions of frame
            Thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                                   cv2.THRESH_BINARY_INV, 11, 2)
            
            cv2.imshow('Thresh', Thresh)
            # define q as exit button
            if cv2.waitKey(25) & 0xFF == ord('q'):
                    break
    
    # Break the loop 
    else: 
        break
 
# release the video capture object
cap.release()
# Closes all the windows currently opened.
cv2.destroyAllWindows()

# %%
# Smoothing a video means removing the sharpness of the video and providing a blurriness to the video. 
# There are various methods for smoothing such as cv2.Gaussianblur(), cv2.medianBlur(), cv2.bilateralFilter().

base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cap = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 

while (cap.isOpened()):
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True: 
            frame = cv2.resize(frame, (540, 380), fx = 0, fy = 0, interpolation = cv2.INTER_CUBIC)
            
            # Display resulting frame
            cv2.imshow('Frame', frame)
            
            # using cv2.Gaussianblur() method to blur the video
            # (5, 5) is the kernel size for blurring.
            gaussianblur = cv2.GaussianBlur(frame, (5, 5), 0) 
            cv2.imshow('gblur', gaussianblur)
            # define q as exit button
            if cv2.waitKey(25) & 0xFF == ord('q'):
                    break
    
    # Break the loop 
    else: 
        break
 
# release the video capture object
cap.release()
# Closes all the windows currently opened.
cv2.destroyAllWindows()

# %%
# Edge detection is a useful technique to detect the edges of surfaces and objects in the video. 
# Edge detection involves the following steps: 
# Noise reduction
# Gradient calculation
# Non-maximum suppression
# Double threshold
# Edge tracking by hysteresis

base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cap = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 

while (cap.isOpened()):
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True: 
            frame = cv2.resize(frame, (540, 380), fx = 0, fy = 0, interpolation = cv2.INTER_CUBIC)
            
            # Display resulting frame
            cv2.imshow('Frame', frame)
            
            # using cv2.Canny() for edge detection.
            edge_detect = cv2.Canny(frame, 100, 200)
            cv2.imshow('Edge detect', edge_detect)
            # define q as exit button
            if cv2.waitKey(25) & 0xFF == ord('q'):
                    break
    
    # Break the loop 
    else: 
        break
# release the video capture object
cap.release()
# Closes all the windows currently opened.
cv2.destroyAllWindows()

# %%
# Bitwise operations are useful to mask different frames of a video together. 
# Bitwise operations are just like AND, OR, NOT, XOR.

base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cap = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 

while (cap.isOpened()):
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True: 
            frame = cv2.resize(frame, (540, 380), fx = 0, fy = 0, interpolation = cv2.INTER_CUBIC)
            
            # Display resulting frame
            cv2.imshow('Frame', frame)
            
            # conversion of BGR to grayscale is necessary to apply this operation
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
         
            _, mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
         
            # apply NOT operation on image and mask generated by thresholding
            BIT = cv2.bitwise_not(frame, frame, mask = mask)
            cv2.imshow('BIT', BIT)
        
            # define q as exit button
            if cv2.waitKey(25) & 0xFF == ord('q'):
                    break
    
    # Break the loop 
    else: 
        break
# release the video capture object
cap.release()
# Closes all the windows currently opened.
cv2.destroyAllWindows()

# %% [markdown]
# # Writing to video with OpenCV

# %%
base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cap = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 

output = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*'MPEG'), 30, (1080, 1920))

while (cap.isOpened()):
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True: 
            # adding rectangle on each frame 
            cv2.rectangle(frame, (100, 100), (500, 500), (0, 255, 0), 3) 
              
            # writing the new frame in output 
            output.write(frame) 
            cv2.imshow("output", frame) 
        
            # define q as exit button
            if cv2.waitKey(25) & 0xFF == ord('q'):
                    break
    
    # Break the loop 
    else: 
        break
# release the video capture object
cap.release()
output.release()
# Closes all the windows currently opened.
cv2.destroyAllWindows()

# %% [markdown]
# # Write text on video

# %%
# Syntax : cv2.putText(frame, Text, org, font, color, thickness)
# Parameters:
# frame: current running frame of the video.
# Text: The text string to be inserted.
# org: bottom-left corner of the text string
# font: the type of font to be used.
# color: the colour of the font.
# thickness: the thickness of the font

base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset"
cap = cv2.VideoCapture(base_path + '\VideoData\seg_comp1.mp4') 

# Check if camera opened successfully 
if (cap.isOpened() == False): 
    print("Error opening video file") 

# Read until video is completed 
while(cap.isOpened()): 
      
# Capture frame-by-frame
    
    ret, frame = cap.read() 
    if ret == True:
        font = cv2.FONT_HERSHEY_SIMPLEX 
  
        # Use putText() method for inserting text on video 
        cv2.putText(frame, 'TEXT ON VIDEO', (50, 50), font, 1, (0, 255, 255), 2, cv2.LINE_4) 
        # Display resulting frame 
        cv2.imshow('Frame', frame) 
          
        # Press Q on keyboard to exit 
        if cv2.waitKey(25) & 0xFF == ord('q'): 
            break
  
# Break the loop 
    else: 
        break
# When everything done, release video capture object 
cap.release() 
# Closes all frames 
cv2.destroyAllWindows()

# %% [markdown]
# # GIF/Video From Images With Python Pillow

# %%
# using pillow
from PIL import Image
import glob

# Open image file using Pillow 
img1 = Image.open(r'C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image\image0.jpg') 
 
# Display the image 
# img1.show()  

# Get some information about image 
print(f"Image format: {img1.format}") 
print(f"Image size: {img1.size}")
# Out:
# Image format: JPEG
# Image size: (1280, 720)

# %%
base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image"

image_names = []
image_list = []

## by for loop
# for filename in sorted(glob.glob(base_path+ r'\*.jpg'), key=len):
#     image_names.append(filename)
#     im = Image.open(filename)
#     image_list.append(im)
# image_names[0:7]

## by list 
image_list = [Image.open(filename) for filename in sorted(glob.glob(base_path+ r'\*.jpg'), key=len)]

# %%
print(type(image_list))
print(len(image_list))
# Out:
# <class 'list'>
# 54

# %% [markdown]
# https://pomain.medium.com/how-to-build-gif-video-from-images-with-python-pillow-opencv-c3126ce89ca8

# %% [markdown]
# https://stackoverflow.com/questions/4813061/non-alphanumeric-list-order-from-os-listdir

# %% [markdown]
# https://stackoverflow.com/questions/43232813/convert-opencv-image-format-to-pil-image-format

# %%
des_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\VideoData" 
gif = []

for image in image_list:
    gif.append(image)
# gif[0].save('n.gif', save_all=True, optimize=False, append_images=gif[1:], loop=0)
# gif[0].save('newx.gif', save_all=True, append_images=gif[1:])
gif[0].save(des_path+r'\new.gif', save_all=True, append_images=gif[1:])

# %% [markdown]
# # fast video from images

# %%
base_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\seg_image"
des_path = r"C:\Users\SHEHA\Downloads\GitHubRepository\Python2022\ComputerVision\Dataset\VideoData"  

def generate_gif():
    image_folder = base_path+'\.' 
    vid_name = des_path+'\my.avi'
          
    images = [img for img in sorted(os.listdir(image_folder), key=len) if img.endswith(".jpg") or img.endswith(".jpeg") or 
              img.endswith("JPEG") or img.endswith("png")] 
    
    # print(images) 
    frame = cv2.imread(os.path.join(image_folder, images[0]))
    print(frame.shape)
    # setting frame width, height of first image 
    height, width, layers = frame.shape

    # video = cv2.VideoWriter('my.avi', cv2.VideoWriter_fourcc(*'XVID'), 24, (width, height))
    video = cv2.VideoWriter(vid_name, cv2.VideoWriter_fourcc(*'XVID'), 24, (width, height))
    for image in images:
        video.write(cv2.imread(os.path.join(image_folder, image)))  
      
    # Deallocating memories taken for window creation 
    cv2.destroyAllWindows()  
    video.release()  # releasing video generated 
    
generate_gif()
# Out:
# (720, 1280, 3)
