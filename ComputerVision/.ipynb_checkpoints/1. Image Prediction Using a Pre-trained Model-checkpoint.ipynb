# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# Import modules

import numpy as np

from tensorflow.keras.utils import load_img
from keras.applications import vgg16
import matplotlib.pyplot as plt
from pathlib import Path

# %%
from skimage import io

img1 = io.imread("asset/dog.jpg")
io.imshow(img1)

# %% [markdown]
# for more understanding
# https://www.analyticsvidhya.com/blog/2022/09/image-prediction-using-a-pre-trained-model/

# %%
# Image path
path = Path("asset/dog.jpg")

# Load image
img = load_img(path, target_size=(224,224))
image_array = img_to_array(img)

# %%
x_train = np.expand_dims(image_array, axis=0)
print(x_train.shape)

# Normalize the data
x_train = vgg16.preprocess_input(x_train)
data = plt.imread(path)
plt.imshow(data)
plt.show()
# Out:
# (1, 224, 224, 3)

# %%
model = vgg16.VGG16(weights="imagenet")
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 64373286793e3c8b2b4e3219cbf3544b so we will re-download the data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 117s 0us/step

# %%
print(x_train.dtype)
# Out:
# float32

# %%
prediction = model.predict(x_train)
pred = vgg16.decode_predictions(prediction)
print(pred)
# Out:
# 1/1 [==============================] - 1s 702ms/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 2us/step
# [[('n02092339', 'Weimaraner', 0.35159877), ('n02091831', 'Saluki', 0.23923758), ('n02099712', 'Labrador_retriever', 0.08509981), ('n02088466', 'bloodhound', 0.08211558), ('n02100583', 'vizsla', 0.07283479)]]
