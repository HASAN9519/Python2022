# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_csv('Dataset\FuelConsumption.csv')

# %%
data.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
df = data.copy()

# %% [markdown]
# ### Exploratory Data Analysis & Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
df.describe().T
# Out:
#                            count         mean        std     min      25%  \
# MODELYEAR                 1067.0  2014.000000   0.000000  2014.0  2014.00
# ENGINESIZE                1067.0     3.346298   1.415895     1.0     2.00
# CYLINDERS                 1067.0     5.794752   1.797447     3.0     4.00
# FUELCONSUMPTION_CITY      1067.0    13.296532   4.101253     4.6    10.25
# FUELCONSUMPTION_HWY       1067.0     9.474602   2.794510     4.9     7.50
# FUELCONSUMPTION_COMB      1067.0    11.580881   3.485595     4.7     9.00
# FUELCONSUMPTION_COMB_MPG  1067.0    26.441425   7.468702    11.0    21.00
# CO2EMISSIONS              1067.0   256.228679  63.372304   108.0   207.00
#
#                              50%      75%     max
# MODELYEAR                 2014.0  2014.00  2014.0
# ENGINESIZE                   3.4     4.30     8.4
# CYLINDERS                    6.0     8.00    12.0
# FUELCONSUMPTION_CITY        12.6    15.55    30.2
# FUELCONSUMPTION_HWY          8.8    10.85    20.5
# FUELCONSUMPTION_COMB        10.9    13.35    25.8
# FUELCONSUMPTION_COMB_MPG    26.0    31.00    60.0
# CO2EMISSIONS               251.0   294.00   488.0

# %%
df.MODELYEAR.value_counts()
# Out:
# 2014    1067
# Name: MODELYEAR, dtype: int64

# %%
df.drop(columns=['MODELYEAR'], inplace=True)

# %%
df.head()
# Out:
#     MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0  ACURA         ILX      COMPACT         2.0          4          AS5
# 1  ACURA         ILX      COMPACT         2.4          4           M6
# 2  ACURA  ILX HYBRID      COMPACT         1.5          4          AV7
# 3  ACURA     MDX 4WD  SUV - SMALL         3.5          6          AS6
# 4  ACURA     RDX AWD  SUV - SMALL         3.5          6          AS6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
# 2        Z                   6.0                  5.8                   5.9
# 3        Z                  12.7                  9.1                  11.1
# 4        Z                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# 1                        29           221
# 2                        48           136
# 3                        25           255
# 4                        27           244

# %%
df.select_dtypes('object').columns
# Out:
# Index(['MAKE', 'MODEL', 'VEHICLECLASS', 'TRANSMISSION', 'FUELTYPE'], dtype='object')

# %%
cat_cols = df.select_dtypes('object').columns

# %%
for col in cat_cols:
    counts = df[col].value_counts()
    print(counts)
    print('===================')
# Out:
# FORD             90
# CHEVROLET        86
# BMW              64
# MERCEDES-BENZ    59
# GMC              49
# AUDI             49
# TOYOTA           49
# PORSCHE          44
# VOLKSWAGEN       42
# DODGE            39
# MINI             36
# NISSAN           33
# KIA              33
# CADILLAC         32
# JEEP             31
# MAZDA            27
# HYUNDAI          24
# SUBARU           23
# JAGUAR           22
# LEXUS            22
# HONDA            21
# INFINITI         21
# CHRYSLER         19
# LAND ROVER       19
# MITSUBISHI       16
# BUICK            16
# RAM              13
# ACURA            12
# VOLVO            11
# LINCOLN          11
# FIAT             10
# SCION             9
# BENTLEY           8
# ROLLS-ROYCE       7
# ASTON MARTIN      7
# MASERATI          6
# LAMBORGHINI       3
# SMART             2
# SRT               2
# Name: MAKE, dtype: int64
# ===================
# F150 FFV                 8
# F150 FFV 4X4             8
# ACCORD                   6
# FOCUS FFV                6
# BEETLE                   6
#                         ..
# Q50 AWD                  1
# Q50                      1
# SONATA HYBRID LIMITED    1
# SONATA HYBRID            1
# XC90 AWD                 1
# Name: MODEL, Length: 663, dtype: int64
# ===================
# MID-SIZE                    178
# COMPACT                     172
# SUV - SMALL                 154
# SUV - STANDARD              110
# FULL-SIZE                    86
# TWO-SEATER                   71
# SUBCOMPACT                   65
# PICKUP TRUCK - STANDARD      62
# MINICOMPACT                  47
# STATION WAGON - SMALL        36
# VAN - PASSENGER              25
# VAN - CARGO                  22
# MINIVAN                      14
# PICKUP TRUCK - SMALL         12
# SPECIAL PURPOSE VEHICLE       7
# STATION WAGON - MID-SIZE      6
# Name: VEHICLECLASS, dtype: int64
# ===================
# A6     222
# AS6    189
# M6     141
# A8      87
# AS8     80
# AS7     76
# M5      48
# AV      46
# A4      45
# AM7     34
# A5      30
# A7      12
# AV6     11
# AS5     10
# M7       9
# A9       8
# AM6      6
# AV7      5
# AV8      3
# AS9      2
# AM5      2
# AS4      1
# Name: TRANSMISSION, dtype: int64
# ===================
# X    514
# Z    434
# E     92
# D     27
# Name: FUELTYPE, dtype: int64
# ===================

# %%
df.drop(columns=cat_cols, inplace=True)

# %%
df.head()
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0         2.0          4                   9.9                  6.7
# 1         2.4          4                  11.2                  7.7
# 2         1.5          4                   6.0                  5.8
# 3         3.5          6                  12.7                  9.1
# 4         3.5          6                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
# paiplot create a grid of Axes such that each numeric variable in data will by shared across y-axes across a single row and
# x-axes across a single column, hue is name of variable in data to map plot aspects to different colors
sns.pairplot(df, hue='CYLINDERS')

# %%
df.corr()[['CO2EMISSIONS']].sort_values(by=['CO2EMISSIONS'], ascending=False)
# Out:
#                           CO2EMISSIONS
# CO2EMISSIONS                  1.000000
# FUELCONSUMPTION_CITY          0.898039
# FUELCONSUMPTION_COMB          0.892129
# ENGINESIZE                    0.874154
# FUELCONSUMPTION_HWY           0.861748
# CYLINDERS                     0.849685
# FUELCONSUMPTION_COMB_MPG     -0.906394

# %%
sns.heatmap(df.corr()[['CO2EMISSIONS']].sort_values(by=['CO2EMISSIONS'], ascending=False),annot=True) # annot will show value
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Outlier Detection and Treatment

# %%
plt.figure(figsize=(10,7))
sns.set(style='darkgrid')
sns.boxplot(data=df[['FUELCONSUMPTION_CITY', 'FUELCONSUMPTION_COMB', 'ENGINESIZE']])
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df[['FUELCONSUMPTION_HWY', 'CYLINDERS', 'FUELCONSUMPTION_COMB_MPG']])
# Out:
# <AxesSubplot: >

# %%
q1, q3 = np.quantile(df.ENGINESIZE, .25), np.quantile(df.ENGINESIZE, .75)
q1, q3
# Out:
# (2.0, 4.3)

# %%
iqr = q3 - q1
iqr
# Out:
# 2.3

# %%
low_out = np.where(df.ENGINESIZE < q1 - (1.5*iqr))[0]
low_out
# Out:
# array([], dtype=int64)

# %%
len(low_out)
# Out:
# 0

# %%
up_out = np.where(df.ENGINESIZE > q3 + (1.5*iqr))[0]
up_out
# Out:
# array([], dtype=int64)

# %%
len(up_out)
# Out:
# 0

# %%
df.drop(low_out, inplace=True)

# %%
df.drop(up_out, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1065 entries, 0 to 1066
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENGINESIZE                1065 non-null   float64
#  1   CYLINDERS                 1065 non-null   int64
#  2   FUELCONSUMPTION_CITY      1065 non-null   float64
#  3   FUELCONSUMPTION_HWY       1065 non-null   float64
#  4   FUELCONSUMPTION_COMB      1065 non-null   float64
#  5   FUELCONSUMPTION_COMB_MPG  1065 non-null   int64
#  6   CO2EMISSIONS              1065 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 66.6 KB

# %%
df1 = df.copy()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1065 entries, 0 to 1066
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENGINESIZE                1065 non-null   float64
#  1   CYLINDERS                 1065 non-null   int64
#  2   FUELCONSUMPTION_CITY      1065 non-null   float64
#  3   FUELCONSUMPTION_HWY       1065 non-null   float64
#  4   FUELCONSUMPTION_COMB      1065 non-null   float64
#  5   FUELCONSUMPTION_COMB_MPG  1065 non-null   int64
#  6   CO2EMISSIONS              1065 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 98.9 KB

# %%
q1, q3 = np.quantile(df1.FUELCONSUMPTION_CITY, .25), np.quantile(df1.FUELCONSUMPTION_CITY, .75)
iqr = q3 - q1
low_out = np.where(df1.FUELCONSUMPTION_CITY < q1 - (1.5*iqr))[0]
up_out = np.where(df1.FUELCONSUMPTION_CITY > q3 + (1.5*iqr))[0]
print(low_out)
print(up_out)
print(len(low_out))
print(len(up_out))
# Out:
# []
# [449 606]
# 0
# 2

# %%
type(low_out)
# Out:
# numpy.ndarray

# %%
df1.drop(low_out, axis=0, inplace=True)
df1.drop(up_out,  axis=0, inplace=True)
df1.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [473], in <cell line: 2>()
#       1 df1.drop(low_out, axis=0, inplace=True)
# ----> 2 df1.drop(up_out,  axis=0, inplace=True)
#       3 df1.info()
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: '[449] not found in axis'

# %%
class OutlierTreatment:
    def __init__(self, DataFrame):
        self.DataFrame = DataFrame
        
    def getInfo(self):
        return (self.DataFrame.head())
    
    def outlier(self):
        q1, q3 = np.quantile(self.DataFrame, .25), np.quantile(self.DataFrame, .75)
        iqr = q3 - q1
        low_out = np.where(self.DataFrame < q1 - (1.5*iqr))[0]
        up_out  = np.where(self.DataFrame > q3 + (1.5*iqr))[0]
        return low_out,up_out
        
    def countoutlier(self):
        a,b=self.outlier()
        return f'lower outlier is {len(a)} and upper outlier is {len(b)}'       
            
    def cleanoutlier(DataFrame):
        a,b=self.outlier()
        if (len(a)>5 or len(b)>5):
            DataFrame.drop(a, inplace=True)
            DataFrame.drop(b, inplace=True)
            return DataFrame.info()
        else:
            return f'not too much'

# %%
d = OutlierTreatment(df1[['CYLINDERS']])
d.outlier()
# Out:
# (array([], dtype=int64),
#  array([ 12,  13,  18,  35,  46,  47,  50,  51,  69,  71,  73,  74, 112,
#         609, 610, 611, 894, 895, 896, 897, 898, 899, 900], dtype=int64))

# %%
d = OutlierTreatment(df1[['FUELCONSUMPTION_COMB_MPG']])
d.outlier()
# Out:
# (array([], dtype=int64),
#  array([   2,  333,  400,  463,  470,  491,  492,  628,  629,  658,  796,
#          903,  940,  941,  957,  958,  959, 1012], dtype=int64))

# %%
d = OutlierTreatment(df1[['FUELCONSUMPTION_CITY']])
d.outlier()
d.cleanoutlier(df1)
# Out:
# 'not too much'

# %%
#d = OutlierTreatment(df1[['FUELCONSUMPTION_COMB_MPG']])
d.countoutlier()
# Out:
# 'lower outlier is 0 and upper outlier is 18'

# %%
d.outlier()
# Out:
# (array([], dtype=int64),
#  array([   2,  333,  400,  463,  470,  491,  492,  628,  629,  658,  796,
#          903,  940,  941,  957,  958,  959, 1012], dtype=int64))

# %%
d.cleanoutlier(df1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [399], in <cell line: 1>()
# ----> 1 d.cleanoutlier(df1)
#
# Input In [389], in OutlierTreatment.cleanoutlier(self, DataFrame)
#      21 if (len(a)>5 or len(b)>5):
#      22     DataFrame.drop(a, inplace=True)
# ---> 23     DataFrame.drop(b, inplace=True)
#      24     return DataFrame.info()
#      25 else:
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: '[940, 941] not found in axis'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1037 entries, 0 to 1066
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENGINESIZE                1037 non-null   float64
#  1   CYLINDERS                 1037 non-null   int64
#  2   FUELCONSUMPTION_CITY      1037 non-null   float64
#  3   FUELCONSUMPTION_HWY       1037 non-null   float64
#  4   FUELCONSUMPTION_COMB      1037 non-null   float64
#  5   FUELCONSUMPTION_COMB_MPG  1037 non-null   int64
#  6   CO2EMISSIONS              1037 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 97.1 KB

# %%
display(df1.iloc[[200]])
# Out:
#      ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 201         2.0          4                   8.7                  5.1
#
#      FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 201                   7.1                        40           192

# %%
d = OutlierTreatment(df1[['FUELCONSUMPTION_CITY']])
d.outlier()
# Out:
# (array([], dtype=int64),
#  array([182, 212, 214, 216, 218, 220, 222, 225, 228, 344, 346, 348, 349,
#         351, 362, 436, 438, 440, 442, 444, 446, 449, 452, 476, 642, 648,
#         654, 687], dtype=int64))

# %%
d.countoutlier()
# Out:
# 'lower outlier is 0 and upper outlier is 28'

# %%
d.cleanoutlier(df1)
# Out:
# (array([], dtype=int64),
#  array([182, 212, 214, 216, 218, 220, 222, 225, 228, 344, 346, 348, 349,
#         351, 362, 436, 438, 440, 442, 444, 446, 449, 452, 476, 642, 648,
#         654, 687], dtype=int64))

# %%
d = OutlierTreatment(df1[['FUELCONSUMPTION_HWY']])
d.countoutlier()
# Out:
# 'lower outlier is 0 and upper outlier is 37'

# %%
d = OutlierTreatment(df1[['FUELCONSUMPTION_COMB']])
d.countoutlier()
# Out:
# 'lower outlier is 0 and upper outlier is 32'

# %%
d = OutlierTreatment(df1[['FUELCONSUMPTION_COMB_MPG']])
d.countoutlier()
# Out:
# 'lower outlier is 0 and upper outlier is 13'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1037 entries, 0 to 1066
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENGINESIZE                1037 non-null   float64
#  1   CYLINDERS                 1037 non-null   int64
#  2   FUELCONSUMPTION_CITY      1037 non-null   float64
#  3   FUELCONSUMPTION_HWY       1037 non-null   float64
#  4   FUELCONSUMPTION_COMB      1037 non-null   float64
#  5   FUELCONSUMPTION_COMB_MPG  1037 non-null   int64
#  6   CO2EMISSIONS              1037 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 97.1 KB

# %%
df1.columns[1]
# Out:
# 'CYLINDERS'

# %%
my_dataframe =  df1.copy()

# %%
class MyClass:

    def __init__(self, DataFrame):
        self.DataFrame = DataFrame
    def __repr__(self,DataFrame):
        return self.DataFrame
    def getInfo(self):
        return (self.DataFrame)
a = MyClass(my_dataframe)

# %%
a.getInfo()
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1065 rows x 7 columns]

# %%
my_dataframe
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1065 rows x 7 columns]

# %%
a = MyClass(df1)

# %%
def getInfo(self) -> str:
        return (self.data)
    def detect(self, column):
        pass
    
    def remove(self, column):
        pass
    def __repr__(self):
        return self.data

# %%
p1 = Product(243, 'IPHONE', 120000.00)
print(p1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 2>()
#       1 p1 = Product(243, 'IPHONE', 120000.00)
# ----> 2 print(p1)
#
# TypeError: __str__ returned non-string (type int)

# %%
class Product:
    # Class or GLobal Attributes
    platform = 'AMAZON'

    # Constructor is foundation to create objects from a class
    def __init__(self, pid: int, title: str, price: float) -> None:
        self.pid = pid
        self.title = title
        self.price = price
    
    # when functions are inside class they are called Methods 
    def getInfo(self) -> str:
        return (self.pid)

    def getDiscount(self) -> float:
        return self.price - (self.price * (15/100))
    
    def __repr__(self):
        return f'Product(pid={self.pid})'

# %%
p1 = Product(243, 'IPHONE', 120000.00)
print(p1)
# Out:
# Product(pid=243)

# %%
p1.getInfo()
# Out:
# 243

# %%
p1
# Out:
# Product(pid=243)

# %%
data = {'1' : ['g', 'e', 'e'], 
        '2' : ['k', 's', 'f'], 
        '3' : ['o', 'r', 'g'], 
        '4' : ['e', 'e', 'k']}
df = pd.DataFrame(data)
display(df)
# Out:
#    1  2  3  4
# 0  g  k  o  e
# 1  e  s  r  e
# 2  e  f  g  k
